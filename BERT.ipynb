# %%
import pandas as pd
import numpy as np
import os
import glob
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
from keras.models import Sequential
from keras.models import Sequential
from keras.layers import LSTM, Dense

# %%
# !pip install -U "tensorflow==2.11.*"
# !pip install "tf-models-official==2.11.*"
# !pip install -U "tensorflow-text==2.11.*"
import tensorflow as tf
print(tf.__version__)

import tensorflow_text as text
print(text.__version__)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 588.3/588.3 MB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 4.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 3.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 439.2/439.2 kB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 2.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.12.0
#     Uninstalling tensorflow-estimator-2.12.0:
#       Successfully uninstalled tensorflow-estimator-2.12.0
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.7.2
#     Uninstalling tensorboard-data-server-0.7.2:
#       Successfully uninstalled tensorboard-data-server-0.7.2
#   Attempting uninstall: protobuf
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_dir='/content/drive/MyDrive/Mouse-Dynamics-Challenge-master/training_files'

# %%
test_data_dir='/content/drive/MyDrive/Mouse-Dynamics-Challenge-master/test_files'

# %%
user_names=glob.glob(os.path.join(data_dir,'*'))

# %%
test_user_names=glob.glob(os.path.join(test_data_dir,'*'))

# %%
user_names
# Out:
# ['/content/drive/MyDrive/Mouse-Dynamics-Challenge-master/training_files/user35',
#  '/content/drive/MyDrive/Mouse-Dynamics-Challenge-master/training_files/user16',
#  '/content/drive/MyDrive/Mouse-Dynamics-Challenge-master/training_files/user7',
#  '/content/drive/MyDrive/Mouse-Dynamics-Challenge-master/training_files/user9',
#  '/content/drive/MyDrive/Mouse-Dynamics-Challenge-master/training_files/user29',
#  '/content/drive/MyDrive/Mouse-Dynamics-Challenge-master/training_files/user23',
#  '/content/drive/MyDrive/Mouse-Dynamics-Challenge-master/training_files/user21',
#  '/content/drive/MyDrive/Mouse-Dynamics-Challenge-master/training_files/user20',
#  '/content/drive/MyDrive/Mouse-Dynamics-Challenge-master/training_files/user12',
#  '/content/drive/MyDrive/Mouse-Dynamics-Challenge-master/training_files/user15']

# %%
test_user_names
# Out:
# ['/content/drive/MyDrive/Mouse-Dynamics-Challenge-master/test_files/user9',
#  '/content/drive/MyDrive/Mouse-Dynamics-Challenge-master/test_files/user7',
#  '/content/drive/MyDrive/Mouse-Dynamics-Challenge-master/test_files/user35',
#  '/content/drive/MyDrive/Mouse-Dynamics-Challenge-master/test_files/user23',
#  '/content/drive/MyDrive/Mouse-Dynamics-Challenge-master/test_files/user29',
#  '/content/drive/MyDrive/Mouse-Dynamics-Challenge-master/test_files/user21',
#  '/content/drive/MyDrive/Mouse-Dynamics-Challenge-master/test_files/user20',
#  '/content/drive/MyDrive/Mouse-Dynamics-Challenge-master/test_files/user16',
#  '/content/drive/MyDrive/Mouse-Dynamics-Challenge-master/test_files/user12',
#  '/content/drive/MyDrive/Mouse-Dynamics-Challenge-master/test_files/user15']

# %%
files_dict={}
for u in user_names:
    files_dict[os.path.basename(u)]=glob.glob(os.path.join(u,'*'))

# %%
test_files_dict={}
for u in test_user_names:
    test_files_dict[os.path.basename(u)]=glob.glob(os.path.join(u,'*'))

# %%
files_dict
# Out:
# {'user35': ['/content/drive/MyDrive/Mouse-Dynamics-Challenge-master/training_files/user35/session_3412209090',
#   '/content/drive/MyDrive/Mouse-Dynamics-Challenge-master/training_files/user35/session_6509784211',
#   '/content/drive/MyDrive/Mouse-Dynamics-Challenge-master/training_files/user35/session_5394017914',
#   '/content/drive/MyDrive/Mouse-Dynamics-Challenge-master/training_files/user35/session_1909471574',
#   '/content/drive/MyDrive/Mouse-Dynamics-Challenge-master/training_files/user35/session_6820312264'],
#  'user16': ['/content/drive/MyDrive/Mouse-Dynamics-Challenge-master/training_files/user16/session_0735651357',
#   '/content/drive/MyDrive/Mouse-Dynamics-Challenge-master/training_files/user16/session_1658051584',
#   '/content/drive/MyDrive/Mouse-Dynamics-Challenge-master/training_files/user16/session_1607878631',
#   '/content/drive/MyDrive/Mouse-Dynamics-Challenge-master/training_files/user16/session_6961018175',
# ...

# %%
test_files_dict
# Out:
# {'user9': ['/content/drive/MyDrive/Mouse-Dynamics-Challenge-master/test_files/user9/session_0510101673',
#   '/content/drive/MyDrive/Mouse-Dynamics-Challenge-master/test_files/user9/session_1471802603',
#   '/content/drive/MyDrive/Mouse-Dynamics-Challenge-master/test_files/user9/session_1177848198',
#   '/content/drive/MyDrive/Mouse-Dynamics-Challenge-master/test_files/user9/session_1067969410',
#   '/content/drive/MyDrive/Mouse-Dynamics-Challenge-master/test_files/user9/session_0703562668',
#   '/content/drive/MyDrive/Mouse-Dynamics-Challenge-master/test_files/user9/session_0249395771',
#   '/content/drive/MyDrive/Mouse-Dynamics-Challenge-master/test_files/user9/session_1428731346',
#   '/content/drive/MyDrive/Mouse-Dynamics-Challenge-master/test_files/user9/session_1388817097',
#   '/content/drive/MyDrive/Mouse-Dynamics-Challenge-master/test_files/user9/session_0398817787',
#   '/content/drive/MyDrive/Mouse-Dynamics-Challenge-master/test_files/user9/session_1498771725',
# ...

# %%
len(test_files_dict.values())
# Out:
# 10

# %%
len(files_dict.values())
# Out:
# 10

# %%
final_df=pd.DataFrame()
for u in user_names:
    files=files_dict[os.path.basename(u)]
    for f in files:
        csv=pd.read_csv(f)
        csv['user']=os.path.basename(u)
        csv['session']=os.path.basename(f)
        final_df=pd.concat([final_df,csv],ignore_index=True)

# %%
test_final_df=pd.DataFrame()
for u in test_user_names:
    test_files=test_files_dict[os.path.basename(u)]
    for f in test_files:
        test_csv=pd.read_csv(f)
        test_csv['user']=os.path.basename(u)
        test_csv['session']=os.path.basename(f)
        test_final_df=pd.concat([test_final_df,test_csv],ignore_index=True)

# %%
final_df.head(10000)
# Out:
#       record timestamp  client timestamp    button    state    x    y    user  \
# 0                0.000             0.000  NoButton     Move  118  213  user35
# 1                0.185             0.172  NoButton     Move  119  213  user35
# 2                0.615             0.609  NoButton     Move  120  213  user35
# 3                0.744             0.733  NoButton     Move  121  212  user35
# 4                0.984             0.967  NoButton     Move  121  211  user35
# ...                ...               ...       ...      ...  ...  ...     ...
# 9995          6819.765          6819.756  NoButton     Move   54  132  user35
# 9996          6819.896          6819.896  NoButton     Move   54  124  user35
# 9997          6820.023          6820.005  NoButton     Move   42  124  user35
# 9998          6820.206          6820.208  NoButton     Move   41  124  user35
# 9999          6820.257          6820.270      Left  Pressed   41  124  user35
#
#                  session
# ...

# %%
test_final_df.head()
# Out:
#    record timestamp  client timestamp    button state    x    y   user  \
# 0               0.0             0.000  NoButton  Move  276   62  user9
# 1               0.1             0.016  NoButton  Move  270   89  user9
# 2               0.1             0.016  NoButton  Move  263  120  user9
# 3               0.1             0.032  NoButton  Move  252  151  user9
# 4               0.1             0.032  NoButton  Move  239  180  user9
#
#               session
# 0  session_0510101673
# 1  session_0510101673
# 2  session_0510101673
# 3  session_0510101673
# 4  session_0510101673

# %%
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from keras.utils import to_categorical


# Encoding categorical columns
label_encoder = LabelEncoder()

frames = [final_df, test_final_df]

final_df['origin'] = 'train'
test_final_df['origin'] = 'test'


merged_df = pd.concat(frames)


#merged_df['button_encoded'] = label_encoder.fit_transform(merged_df['button'])
#merged_df['state_encoded'] = label_encoder.fit_transform(merged_df['state'])
# merged_df['session_encoded'] = label_encoder.fit_transform(merged_df['session'])
# merged_df['user_encoded'] = label_encoder.fit_transform(merged_df['user'])

#merged_df['user_encoded'] = label_encoder.fit_transform(merged_df['user'])


# Split the merged DataFrame back into two
final_df = merged_df[merged_df['origin'] == 'train'].drop('origin', axis=1)
test_final_df = merged_df[merged_df['origin'] == 'test'].drop('origin', axis=1)


# test_final_df['button_encoded'] = label_encoder.fit_transform(test_final_df['button'])
# test_final_df['state_encoded'] = label_encoder.fit_transform(test_final_df['state'])
# test_final_df['session_encoded'] = label_encoder.fit_transform(test_final_df['session'])
# test_final_df = pd.get_dummies(test_final_df, columns=['user'])

# Normalizing numerical columns
# scaler = MinMaxScaler()
# numerical_columns = ['record timestamp', 'client timestamp', 'x', 'y']
# final_df[numerical_columns] = scaler.fit_transform(final_df[numerical_columns])

# scaler = MinMaxScaler()
# numerical_columns = ['record timestamp', 'client timestamp', 'x', 'y']
# test_final_df[numerical_columns] = scaler.fit_transform(test_final_df[numerical_columns])

# Displaying the first few rows of the transformed dataset
final_df.head()
# Out:
#    record timestamp  client timestamp    button state    x    y    user  \
# 0             0.000             0.000  NoButton  Move  118  213  user35
# 1             0.185             0.172  NoButton  Move  119  213  user35
# 2             0.615             0.609  NoButton  Move  120  213  user35
# 3             0.744             0.733  NoButton  Move  121  212  user35
# 4             0.984             0.967  NoButton  Move  121  211  user35
#
#               session
# 0  session_3412209090
# 1  session_3412209090
# 2  session_3412209090
# 3  session_3412209090
# 4  session_3412209090

# %%
# Convert numerical columns to strings and concatenate
final_df['combined'] = final_df[['record timestamp', 'client timestamp', 'x', 'y', 'button', 'state']].astype(str).agg(' '.join, axis=1)

# %%
# Convert numerical columns to strings and concatenate
test_final_df['combined'] = test_final_df[['record timestamp', 'client timestamp', 'x', 'y', 'button', 'state']].astype(str).agg(' '.join, axis=1)

# %%
final_df
# Out:
#          record timestamp  client timestamp    button     state    x    y  \
# 0                   0.000             0.000  NoButton      Move  118  213
# 1                   0.185             0.172  NoButton      Move  119  213
# 2                   0.615             0.609  NoButton      Move  120  213
# 3                   0.744             0.733  NoButton      Move  121  212
# 4                   0.984             0.967  NoButton      Move  121  211
# ...                   ...               ...       ...       ...  ...  ...
# 2253811         13384.228         13384.324  NoButton      Drag  500  794
# 2253812         13384.340         13384.433  NoButton      Drag  497  865
# 2253813         13384.546         13384.636  NoButton      Drag  497  890
# 2253814         13385.179         13385.276  NoButton      Drag  497  892
# 2253815         13385.180         13385.276      Left  Released  497  892
#
#            user             session  \
# 0        user35  session_3412209090
# ...

# %%
final_df.drop(columns=['record timestamp', 'client timestamp', 'button', 'state', 'x', 'y', 'user', 'session'], inplace=True)

# %%
test_final_df.drop(columns=['record timestamp', 'client timestamp', 'button', 'state', 'x', 'y', 'user', 'session'], inplace=True)

# %%
#@title Choose a BERT model to fine-tune

bert_model_name = 'small_bert/bert_en_uncased_L-4_H-512_A-8'  #@param ["bert_en_uncased_L-12_H-768_A-12", "bert_en_cased_L-12_H-768_A-12", "bert_multi_cased_L-12_H-768_A-12", "small_bert/bert_en_uncased_L-2_H-128_A-2", "small_bert/bert_en_uncased_L-2_H-256_A-4", "small_bert/bert_en_uncased_L-2_H-512_A-8", "small_bert/bert_en_uncased_L-2_H-768_A-12", "small_bert/bert_en_uncased_L-4_H-128_A-2", "small_bert/bert_en_uncased_L-4_H-256_A-4", "small_bert/bert_en_uncased_L-4_H-512_A-8", "small_bert/bert_en_uncased_L-4_H-768_A-12", "small_bert/bert_en_uncased_L-6_H-128_A-2", "small_bert/bert_en_uncased_L-6_H-256_A-4", "small_bert/bert_en_uncased_L-6_H-512_A-8", "small_bert/bert_en_uncased_L-6_H-768_A-12", "small_bert/bert_en_uncased_L-8_H-128_A-2", "small_bert/bert_en_uncased_L-8_H-256_A-4", "small_bert/bert_en_uncased_L-8_H-512_A-8", "small_bert/bert_en_uncased_L-8_H-768_A-12", "small_bert/bert_en_uncased_L-10_H-128_A-2", "small_bert/bert_en_uncased_L-10_H-256_A-4", "small_bert/bert_en_uncased_L-10_H-512_A-8", "small_bert/bert_en_uncased_L-10_H-768_A-12", "small_bert/bert_en_uncased_L-12_H-128_A-2", "small_bert/bert_en_uncased_L-12_H-256_A-4", "small_bert/bert_en_uncased_L-12_H-512_A-8", "small_bert/bert_en_uncased_L-12_H-768_A-12", "albert_en_base", "electra_small", "electra_base", "experts_pubmed", "experts_wiki_books", "talking-heads_base"]

map_name_to_handle = {
    'bert_en_uncased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_L-12_H-768_A-12/3',
    'bert_en_cased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_cased_L-12_H-768_A-12/3',
    'bert_multi_cased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_multi_cased_L-12_H-768_A-12/3',
    'small_bert/bert_en_uncased_L-2_H-128_A-2':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-2_H-128_A-2/1',
    'small_bert/bert_en_uncased_L-2_H-256_A-4':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-2_H-256_A-4/1',
    'small_bert/bert_en_uncased_L-2_H-512_A-8':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-2_H-512_A-8/1',
    'small_bert/bert_en_uncased_L-2_H-768_A-12':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-2_H-768_A-12/1',
    'small_bert/bert_en_uncased_L-4_H-128_A-2':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-4_H-128_A-2/1',
    'small_bert/bert_en_uncased_L-4_H-256_A-4':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-4_H-256_A-4/1',
    'small_bert/bert_en_uncased_L-4_H-512_A-8':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-4_H-512_A-8/1',
    'small_bert/bert_en_uncased_L-4_H-768_A-12':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-4_H-768_A-12/1',
    'small_bert/bert_en_uncased_L-6_H-128_A-2':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-6_H-128_A-2/1',
    'small_bert/bert_en_uncased_L-6_H-256_A-4':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-6_H-256_A-4/1',
    'small_bert/bert_en_uncased_L-6_H-512_A-8':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-6_H-512_A-8/1',
    'small_bert/bert_en_uncased_L-6_H-768_A-12':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-6_H-768_A-12/1',
    'small_bert/bert_en_uncased_L-8_H-128_A-2':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-8_H-128_A-2/1',
    'small_bert/bert_en_uncased_L-8_H-256_A-4':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-8_H-256_A-4/1',
    'small_bert/bert_en_uncased_L-8_H-512_A-8':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-8_H-512_A-8/1',
    'small_bert/bert_en_uncased_L-8_H-768_A-12':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-8_H-768_A-12/1',
    'small_bert/bert_en_uncased_L-10_H-128_A-2':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-10_H-128_A-2/1',
    'small_bert/bert_en_uncased_L-10_H-256_A-4':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-10_H-256_A-4/1',
    'small_bert/bert_en_uncased_L-10_H-512_A-8':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-10_H-512_A-8/1',
    'small_bert/bert_en_uncased_L-10_H-768_A-12':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-10_H-768_A-12/1',
    'small_bert/bert_en_uncased_L-12_H-128_A-2':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-12_H-128_A-2/1',
    'small_bert/bert_en_uncased_L-12_H-256_A-4':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-12_H-256_A-4/1',
    'small_bert/bert_en_uncased_L-12_H-512_A-8':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-12_H-512_A-8/1',
    'small_bert/bert_en_uncased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-12_H-768_A-12/1',
    'albert_en_base':
        'https://tfhub.dev/tensorflow/albert_en_base/2',
    'electra_small':
        'https://tfhub.dev/google/electra_small/2',
    'electra_base':
        'https://tfhub.dev/google/electra_base/2',
    'experts_pubmed':
        'https://tfhub.dev/google/experts/bert/pubmed/2',
    'experts_wiki_books':
        'https://tfhub.dev/google/experts/bert/wiki_books/2',
    'talking-heads_base':
        'https://tfhub.dev/tensorflow/talkheads_ggelu_bert_en_base/1',
}

map_model_to_preprocess = {
    'bert_en_uncased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'bert_en_cased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_cased_preprocess/3',
    'small_bert/bert_en_uncased_L-2_H-128_A-2':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-2_H-256_A-4':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-2_H-512_A-8':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-2_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-4_H-128_A-2':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-4_H-256_A-4':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-4_H-512_A-8':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-4_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-6_H-128_A-2':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-6_H-256_A-4':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-6_H-512_A-8':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-6_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-8_H-128_A-2':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-8_H-256_A-4':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-8_H-512_A-8':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-8_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-10_H-128_A-2':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-10_H-256_A-4':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-10_H-512_A-8':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-10_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-12_H-128_A-2':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-12_H-256_A-4':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-12_H-512_A-8':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'bert_multi_cased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_multi_cased_preprocess/3',
    'albert_en_base':
        'https://tfhub.dev/tensorflow/albert_en_preprocess/3',
    'electra_small':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'electra_base':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'experts_pubmed':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'experts_wiki_books':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'talking-heads_base':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
}

tfhub_handle_encoder = map_name_to_handle[bert_model_name]
tfhub_handle_preprocess = map_model_to_preprocess[bert_model_name]

print(f'BERT model selected           : {tfhub_handle_encoder}')
print(f'Preprocess model auto-selected: {tfhub_handle_preprocess}')
# Out:
# BERT model selected           : https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-4_H-512_A-8/1
# Preprocess model auto-selected: https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3

# %%
# !pip install -U "tensorflow==2.8.*"

# %%
# !pip install -U "tensorflow-text==2.13.*"

# %%
# !pip install "tf-models-official==2.13.*"

# %%
import tensorflow_hub as hub

# %%
tfhub_handle_preprocess = 'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3'

# Load pre-trained BERT
bert_preprocess_model = hub.KerasLayer(tfhub_handle_preprocess)
# Group by session and combine text
session_texts = final_df.groupby('session')['combined'].apply(lambda x: ' '.join(x)).reset_index()
text = session_texts['combined']

text_preprocessed = bert_preprocess_model(text)

print(text)

print(f'Keys       : {list(text_preprocessed.keys())}')
print(f'Shape      : {text_preprocessed["input_word_ids"].shape}')

# %%
tfhub_handle_encoder = 'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-4_H-512_A-8/1'

# %%
bert_model = hub.KerasLayer(tfhub_handle_encoder)

# %%
bert_results = bert_model(text)

print(f'Loaded BERT: {tfhub_handle_encoder}')
print(f'Pooled Outputs Shape:{bert_results["pooled_output"].shape}')
print(f'Pooled Outputs Values:{bert_results["pooled_output"][0, :12]}')
print(f'Sequence Outputs Shape:{bert_results["sequence_output"].shape}')
print(f'Sequence Outputs Values:{bert_results["sequence_output"][0, :12]}')

# %%
# Group by session and combine text
test_session_texts = test_final_df.groupby('session')['combined'].apply(lambda x: ' '.join(x)).reset_index()

# %%
session_texts

# %%
# Encode user labels
label_encoder = LabelEncoder()
session_texts['user_encoded'] = label_encoder.fit_transform(final_df.groupby('session')['user'].first())

# %%
# Encode user labels
label_encoder = LabelEncoder()
test_session_texts['user_encoded'] = label_encoder.fit_transform(test_final_df.groupby('session')['user'].first())

# %%
from transformers import BertTokenizer

# Initialize tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Tokenize
max_length = 512  # BERT has a maximum length of 512 tokens
tokens = session_texts['combined'].apply(lambda x: tokenizer.encode(x, add_special_tokens=True, max_length=max_length, truncation=True))

# Pad sequences to the same length
max_seq_length = 12000  # Could be set to max(tokens.apply(len)) if less than 512
padded_tokens = np.array([i + [0]*(max_seq_length-len(i)) for i in tokens])

# Create attention masks (1 for tokens, 0 for padding)
attention_masks = np.where(padded_tokens != 0, 1, 0)
# Out:
# tokenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]

# %%
from transformers import TFBertModel
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model

# Load pre-trained BERT
bert_model = TFBertModel.from_pretrained('bert-base-uncased')
#bert_model = TFBertModel.from_pretrained('bert-base-uncased', output_hidden_states=False, output_attentions=False)


# Input layers
input_ids = Input(shape=(max_seq_length,), dtype='int32')
attention_mask = Input(shape=(max_seq_length,), dtype='int32')

# BERT layer
# bert_output = bert_model(input_ids, attention_mask=attention_mask)
# sequence_output = bert_output[0]

# Define the model architecture
input_ids = Input(shape=(max_length,), dtype=tf.int32)
attention_mask = Input(shape=(max_length,), dtype=tf.int32)
bert_embedding = bert_model(input_ids, attention_mask=attention_mask)[0]
lstm = LSTM(50, return_sequences=False)(bert_embedding)

# Classification layer
clf_output = sequence_output[:, 0, :]
out = Dense(10, activation='softmax')(clf_output)  # 10 users

# Assemble model
model = Model(inputs=[input_ids, attention_mask], outputs=out)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

y_train = session_texts['user_encoded'].values
X_train = [padded_tokens, attention_masks]

model.fit(X_train, y_train, batch_size=8, epochs=100)
